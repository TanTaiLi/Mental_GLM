# %%
import matplotlib.pyplot as plt
import pickle

# %%
with open('single_loss_curve.pkl', 'rb') as f:
    losses = pickle.load(f)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(0, len(losses)*1, 1), losses, label='Training Loss')
plt.title('Loss Curve')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()

plt.savefig(CFG.graph_name+'.pdf', format='pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 plt.ylabel('Loss')
#       6 plt.legend()
# ----> 8 plt.savefig(CFG.graph_name+'.pdf', format='pdf')
#       9 plt.show()
#
# NameError: name 'CFG' is not defined
