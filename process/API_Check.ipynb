# %%
import json
import random
import openai
from openai import OpenAI
from tqdm import tqdm
import pandas as pd

# %%
df=pd.read_json('/root/autodl-tmp/dataset/OESD-GG-zh_cn-1/api_gen.jsonl', lines=True)

# %%
df
# Out:
#                                                   User  \
# 0    我最近遇到的苦恼是，我周围的人经常炫耀他们的成就和成功，而这让我感到非常不适。我发现自己的好...
# 1    最近我总是感到自己的好胜心过于强烈，特别是当我看到别人炫耀自己的成就时，我会感到非常不适。他...
# 2    我最近遇到的一个苦恼是，我经常被别人的炫耀行为所困扰，这让我感到不舒服。无论是在社交媒体上还...
# 3    我最近一直感到苦恼的是，我对于别人经常炫耀自己的成就和成功感到很不适。每当我听到他们自豪地展...
# 4    我最近感到非常苦恼，因为我发现自己经常被别人的炫耀所影响，导致自己感到不适和焦虑。我对自己的...
# ..                                                 ...
# 394  我最近总是感觉自己总是得罪别人，这让我非常苦恼。不论是在工作中还是生活中，我总是不小心说错话...
# 395  我最近遇到一个非常困扰的问题，就是我总是不小心得罪了别人。无论是在工作上还是在生活中，我总是...
# 396  我总是不经意地得罪别人，这让我感到非常困扰和苦恼。无论是在工作场所还是在生活中，我总是不知道...
# 397  其实，我总是感到很苦恼，因为我总是不经意间得罪了别人。无论是在工作上还是在生活中，我总是会说...
# 398  苦恼的最近我意识到自己总是不小心得罪身边的人，无论是在工作场合还是日常生活中。我常常会说出一...
#
#                                             Assistance
# 0    首先，我想感谢你对自己情绪的诚实和开放。你正在经历的这种情况在心理学中被称为"社会比较理论"...
# 1    你的问题并不微不足道，相反，这是一种被称为"比较焦虑"的常见心理现象。这种现象源于我们的社会...
# 2    我理解你的困扰，你正在经历的可能是“社会比较理论”中的下行比较和上行比较的困扰。下行比较是指...
# 3    你的问题可以被归类为"社会比较焦虑"，这是一种常见的心理现象，它源于我们对自我价值的不断评估...
# ...

# %%
for item in df.User:
    print(item)
    break
# Out:
# 我最近遇到的苦恼是，我周围的人经常炫耀他们的成就和成功，而这让我感到非常不适。我发现自己的好胜心太强，总是希望自己能够取得更多的成就，但是当看到别人取得成功时，我就会感到自卑和沮丧。这种情况经常发生在工作场合或社交场合，不论是同事还是朋友，他们总是不遗余力地展示他们的成就，比如晋升了职位、获得了奖项、完成了一项重要项目等等。每次听到这些消息，我就会感到自己的成就相对较少，甚至开始怀疑自己的能力和价值。我明白每个人都有自己的成就和努力，但是我无法摆脱对比和竞争的心态。这使得我无法真正享受自己的成就，而是只关注别人取得的更大的成功。我知道这样的想法是不健康的，但我很难控制自己的情绪和思维。这种苦恼对我的心理和情绪造成了很大的压力。我感到自己陷入了一个比较和竞争的漩涡中，无法真正放松和快乐。而且，这种情绪也影响了我与他人的关系，我开始对别人的成功感到嫉妒和羡慕，而不是真心为他们感到高兴。我希望能够找到一种方法来摆脱这种不健康的心态，开始真正关注自己的成就和价值。也许我需要更多的自我接受和肯定，以及学会与他人分享快乐和成功，而不是将其作为竞争的对象。我知道这并不容易，但我相信只有这样，我才能真正摆脱这个苦恼，过上更加平静和满足的生活。
